# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout

# %%
data=pd.read_csv("/content/diabetes.csv")
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
X=data.iloc[:, :-1].values #features
Y=data.iloc[:, -1].values  #labels

# %%
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
sh = 8

# %%
model = Sequential()
model.add(Dense(10,input_dim=sh,activation="relu"))
model.add(Dense(5,activation="relu"))
model.add(Dense(1,activation="sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 16)                144
#
#  dense_13 (Dense)            (None, 8)                 136
#
#  dense_14 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 289 (1.13 KB)
# Trainable params: 289 (1.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer ='Adam',loss="BinaryCrossentropy",metrics = ['accuracy'])

# %%
model.fit(X_train,y_train,epochs = 100)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 3s 5ms/step - loss: 0.6610 - accuracy: 0.6433
# Epoch 2/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6241 - accuracy: 0.6612
# Epoch 3/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5965 - accuracy: 0.6678
# Epoch 4/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5737 - accuracy: 0.6792
# Epoch 5/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5551 - accuracy: 0.6922
# Epoch 6/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5382 - accuracy: 0.7020
# Epoch 7/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5234 - accuracy: 0.7085
# Epoch 8/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5115 - accuracy: 0.7199
# Epoch 9/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5005 - accuracy: 0.7264
# Epoch 10/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4920 - accuracy: 0.7264
# Epoch 11/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4842 - accuracy: 0.7264
# Epoch 12/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4773 - accuracy: 0.7394
# Epoch 13/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4712 - accuracy: 0.7362
# Epoch 14/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4652 - accuracy: 0.7427
# Epoch 15/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4595 - accuracy: 0.7557
# Epoch 16/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4548 - accuracy: 0.7638
# Epoch 17/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4506 - accuracy: 0.7704
# Epoch 18/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4467 - accuracy: 0.7720
# Epoch 19/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4442 - accuracy: 0.7801
# Epoch 20/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4400 - accuracy: 0.7866
# Epoch 21/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4383 - accuracy: 0.7785
# Epoch 22/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4351 - accuracy: 0.7932
# Epoch 23/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4318 - accuracy: 0.7899
# Epoch 24/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4302 - accuracy: 0.7899
# Epoch 25/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4278 - accuracy: 0.7899
# Epoch 26/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4260 - accuracy: 0.7964
# Epoch 27/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4250 - accuracy: 0.7932
# Epoch 28/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4236 - accuracy: 0.7948
# Epoch 29/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4221 - accuracy: 0.7899
# Epoch 30/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4203 - accuracy: 0.7883
# Epoch 31/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4183 - accuracy: 0.7915
# Epoch 32/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4175 - accuracy: 0.7899
# Epoch 33/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4171 - accuracy: 0.7899
# Epoch 34/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4151 - accuracy: 0.7899
# Epoch 35/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4142 - accuracy: 0.7866
# Epoch 36/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4128 - accuracy: 0.7980
# Epoch 37/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4119 - accuracy: 0.7997
# Epoch 38/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4109 - accuracy: 0.7932
# Epoch 39/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4103 - accuracy: 0.7997
# Epoch 40/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4089 - accuracy: 0.8013
# Epoch 41/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4082 - accuracy: 0.8013
# Epoch 42/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4078 - accuracy: 0.8046
# Epoch 43/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4072 - accuracy: 0.7980
# Epoch 44/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4063 - accuracy: 0.8029
# Epoch 45/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4060 - accuracy: 0.7997
# Epoch 46/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4048 - accuracy: 0.8013
# Epoch 47/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4033 - accuracy: 0.8046
# Epoch 48/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4025 - accuracy: 0.8062
# Epoch 49/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4023 - accuracy: 0.8029
# Epoch 50/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4018 - accuracy: 0.8029
# Epoch 51/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4013 - accuracy: 0.8046
# Epoch 52/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4008 - accuracy: 0.8046
# Epoch 53/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4000 - accuracy: 0.8078
# Epoch 54/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3993 - accuracy: 0.8111
# Epoch 55/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3987 - accuracy: 0.8094
# Epoch 56/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3992 - accuracy: 0.8111
# Epoch 57/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3992 - accuracy: 0.8062
# Epoch 58/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3969 - accuracy: 0.8127
# Epoch 59/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3964 - accuracy: 0.8062
# Epoch 60/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3957 - accuracy: 0.8127
# Epoch 61/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3950 - accuracy: 0.8143
# Epoch 62/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3947 - accuracy: 0.8143
# Epoch 63/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3940 - accuracy: 0.8143
# Epoch 64/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3935 - accuracy: 0.8176
# Epoch 65/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3929 - accuracy: 0.8192
# Epoch 66/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3936 - accuracy: 0.8160
# Epoch 67/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3919 - accuracy: 0.8257
# Epoch 68/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3913 - accuracy: 0.8160
# Epoch 69/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3907 - accuracy: 0.8192
# Epoch 70/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3901 - accuracy: 0.8192
# Epoch 71/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3900 - accuracy: 0.8208
# Epoch 72/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3894 - accuracy: 0.8208
# Epoch 73/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3889 - accuracy: 0.8208
# Epoch 74/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3876 - accuracy: 0.8160
# Epoch 75/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3874 - accuracy: 0.8225
# Epoch 76/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3869 - accuracy: 0.8225
# Epoch 77/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3859 - accuracy: 0.8192
# Epoch 78/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3853 - accuracy: 0.8225
# Epoch 79/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3842 - accuracy: 0.8241
# Epoch 80/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3855 - accuracy: 0.8225
# Epoch 81/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3834 - accuracy: 0.8290
# Epoch 82/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3833 - accuracy: 0.8241
# Epoch 83/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3821 - accuracy: 0.8274
# Epoch 84/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3812 - accuracy: 0.8274
# Epoch 85/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3804 - accuracy: 0.8257
# Epoch 86/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3804 - accuracy: 0.8274
# Epoch 87/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3799 - accuracy: 0.8290
# Epoch 88/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3788 - accuracy: 0.8274
# Epoch 89/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3781 - accuracy: 0.8241
# Epoch 90/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3776 - accuracy: 0.8290
# Epoch 91/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3776 - accuracy: 0.8257
# Epoch 92/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3766 - accuracy: 0.8290
# Epoch 93/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3766 - accuracy: 0.8274
# Epoch 94/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3760 - accuracy: 0.8257
# Epoch 95/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3769 - accuracy: 0.8274
# Epoch 96/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3745 - accuracy: 0.8339
# Epoch 97/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3754 - accuracy: 0.8339
# Epoch 98/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3743 - accuracy: 0.8355
# Epoch 99/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3735 - accuracy: 0.8339
# Epoch 100/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3727 - accuracy: 0.8274

# %%
graph = model.history.history

# %%
import matplotlib.pyplot as plt

plt.plot(graph['loss'])
